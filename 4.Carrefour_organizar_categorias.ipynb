# %%
import pandas as pd

# %%
datos=pd.read_csv('Carrefour_mas_ofertas.csv')

# %%
df=pd.DataFrame(datos)

# %%
df
# Out:
#                                                   nombre  Precios  \
# 0      Preparado de carne picada de vacuno Carrefour ...   6,71 €
# 1                          Solomillo de pavo 750 g aprox   5,81 €
# 2      Pechuga de Pollo Ecológica Carrefour Bio 500 g...  12,39 €
# 3      Hamburguesas de vacuno ecológica Carrefour Bio...   4,50 €
# 4      Jamoncito de pollo ecológico Carrefour Bio 500...   6,79 €
# ...                                                  ...      ...
# 13984  Pienso de pollo y verduras para perro adulto P...  37,50 €
# 13985  Pomada para proteger la zona del pañal Mitosyl...  21,07 €
# 13986                 Cepillo de dientes medio PHB 2 ud.   6,69 €
# 13987                     Cepillo dental suave PHB 2 ud.   6,69 €
# 13988           Aposito postpicadura niños Orphea 30 ud.   4,15 €
#
#       Precios_unit         categorias   subcategoria precio_oferta
# 0        7,46 €/kg  productos-frescos     carniceria           NaN
# ...

# %%
df['subcategoria'].unique()
# Out:
# array(['carniceria', 'pescaderia', 'frutas', 'verduras-y-hortalizas',
#        'panaderia-tradicional', 'charcuteria', 'quesos',
#        'platos-preparados-cocinados', 'alimentacion', 'lacteos',
#        'desayuno', 'yogures-y-postres', 'dulce',
#        'panaderia-bolleria-y-pasteleria',
#        'conservas-sopas-y-precocinados', 'aperitivos', 'huevos',
#        'rebozados-y-platos-preparados', 'pizzas-congeladas',
#        'verduras-congeladas', 'salteados-congelados', 'helados',
#        'mariscos-congelados', 'pescados-congelados',
#        'gulas-y-surimis-congelados', 'pulpo-calamar-y-sepia-congelados',
#        'refrescos', 'cerveza', 'aguas-y-zumos', 'alcoholes', 'vinos',
#        'cava-y-champagne', 'licores-y-cremas', 'sidra',
#        'cuidado-de-la-ropa', 'papel-y-celulosa', 'productos-para-cocina',
#        'productos-para-bano', 'productos-para-toda-la-casa',
#        'utensilios-de-limpieza', 'conservacion-de-alimentos',
# ...

# %%
df['Categoria_principal'] = df['subcategoria'].replace('carniceria', 'Carne').replace('pescaderia', 'Marisco y pescado').replace('frutas', 'Fruta y verdura').replace('verduras-y-hortalizas', 'Fruta y verdura').replace('panaderia-tradicional', 'Panadería y pastelería').replace('charcuteria', 'Charcutería y quesos').replace('quesos', 'Charcutería y quesos').replace('platos-preparados-cocinados', 'Pizzas y platos preparados').replace('alimentacion', 'Salsas, pasta y refrescos').replace('lacteos', 'leche y mantequilla').replace('desayuno', 'Cereales y galletas').replace('yogures-y-postres', 'Postres y yogures').replace('dulce', 'Azúcar, caramelos y chocolate').replace('panaderia-bolleria-y-pasteleria', 'Panadería y pastelería').replace('conservas-sopas-y-precocinados', 'Conservas, caldos y cremas').replace('aperitivos', 'Aperitivos').replace('huevos', 'Huevos').replace('rebozados-y-platos-preparados', 'Pizzas y platos preparados').replace('pizzas-congeladas', 'Congelados').replace('verduras-congeladas', 'Congelados').replace('salteados-congelados', 'Congelados').replace('helados', 'Congelados').replace('mariscos-congelados', 'Congelados').replace('pescados-congelados', 'Congelados').replace('gulas-y-surimis-congelados', 'Congelados').replace('pulpo-calamar-y-sepia-congelados', 'Congelados').replace('refrescos', 'Agua y refrescos').replace('cerveza', 'Bodega').replace('aguas-y-zumos', 'Zumos').replace('alcoholes', 'Bodega').replace('vinos', 'Bodega').replace('vinos', 'Bodega').replace('cava-y-champagne', 'Bodega').replace('licores-y-cremas', 'Bodega').replace('sidra', 'Bodega').replace('cuidado-de-la-ropa', '').replace('papel-y-celulosa', 'Limpieza y hogar').replace('productos-para-cocina', 'Limpieza y hogar').replace('productos-para-bano', 'Limpieza y hogar').replace('productos-para-toda-la-casa', 'Limpieza y hogar').replace('utensilios-de-limpieza', 'Limpieza y hogar').replace('conservacion-de-alimentos', 'Limpieza y hogar').replace('ambientadores', 'Limpieza y hogar').replace('calzado', 'calzado').replace('menaje', 'Limpieza y hogar').replace('papeleria', 'papeleria').replace('bazar', 'bazar').replace('bano-e-higiene-corporal', 'Cuidado facial y corporal').replace('cabello', 'Cuidado del cabello').replace('cuidado-y-proteccion-corporal', 'Cuidado facial y corporal').replace('boca-y-sonrisa', 'Cuidado facial y corporal').replace('higiene-intima', 'Cuidado facial y corporal').replace('depilacion-y-afeitado', 'Cuidado facial y corporal').replace('cosmetica', 'Cuidado facial y corporal').replace('bienestar-sexual', 'Fitoterapia y parafarmacia').replace('panales-y-toallitas', 'Cuidado facial y corporal').replace('alimentacion-infantil', 'Bebé').replace('perfumeria-e-higiene', 'Cuidado facial y corporal').replace('puericultura', 'Bebé').replace('perros', 'Mascotas').replace('gatos', 'Mascotas').replace('conejos-y-roedores', 'Mascotas').replace('pajaros', 'Mascotas').replace('bebe', 'Bebé').replace('higiene-bucal', 'Cuidado facial y corporal').replace('cuidado-corporal', 'Cuidado facial y corporal').replace('cuidado-e-higiene-facial', 'Cuidado facial y corporal').replace('cuidado-de-manos-y-pies', 'Cuidado facial y corporal').replace('cuidado-de-manos-y-pies', 'Cuidado facial y corporal').replace('nutricion-y-dietetica', 'Fitoterapia y parafarmacia')

# %%
df
# Out:
#                                                   nombre  Precios  \
# 0      Preparado de carne picada de vacuno Carrefour ...   6,71 €
# 1                          Solomillo de pavo 750 g aprox   5,81 €
# 2      Pechuga de Pollo Ecológica Carrefour Bio 500 g...  12,39 €
# 3      Hamburguesas de vacuno ecológica Carrefour Bio...   4,50 €
# 4      Jamoncito de pollo ecológico Carrefour Bio 500...   6,79 €
# ...                                                  ...      ...
# 13984  Pienso de pollo y verduras para perro adulto P...  37,50 €
# 13985  Pomada para proteger la zona del pañal Mitosyl...  21,07 €
# 13986                 Cepillo de dientes medio PHB 2 ud.   6,69 €
# 13987                     Cepillo dental suave PHB 2 ud.   6,69 €
# 13988           Aposito postpicadura niños Orphea 30 ud.   4,15 €
#
#       Precios_unit         categorias   subcategoria precio_oferta  \
# 0        7,46 €/kg  productos-frescos     carniceria           NaN
# ...

# %%
df.to_csv('Carrefour_categorizado.csv', index=False)
