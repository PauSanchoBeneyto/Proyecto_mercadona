# %% [markdown]
# CÓDIGO PARA SEPARAR LA CATEGORIA (LA CUAL ESTABAN JUNTAS), EN CATEGORIA Y SUBCATEGORIA

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b09a15a-caa5-452a-a14f-85e9ce1e9555" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b09a15a-caa5-452a-a14f-85e9ce1e9555">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
datos=pd.read_csv("raw_data.csv")

# %%
df=pd.DataFrame(datos)

# %%
df
# Out:
#                                                   category  \
# 0        perfumeria_e_higiene_cuidado_facial_protector_...
# 1            perfumeria_e_higiene_higiene_intima_compresas
# 2            perfumeria_e_higiene_higiene_intima_compresas
# 3        perfumeria_e_higiene_higiene_bucal_productos_p...
# 4        perfumeria_e_higiene_higiene_bucal_productos_p...
# ...                                                    ...
# 8223987                            fruta_y_verdura_verdura
# 8223988                                      bebidas_aguas
# 8223989                            fruta_y_verdura_verdura
# 8223990                              fruta_y_verdura_fruta
# 8223991                            fruta_y_verdura_verdura
#
#                                                       name description  price  \
# 0           LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
# 1               AUSONIA compresas normal alas bolsa 14 uds         NaN   2.49
# ...

# %%
df["category"].unique()
# Out:
# array(['perfumeria_e_higiene_cuidado_facial_protector_labial',
#        'perfumeria_e_higiene_higiene_intima_compresas',
#        'perfumeria_e_higiene_higiene_bucal_productos_protesicos', ...,
#        'bebe_panales_y_toallitas_otras_marcas',
#        'despensa_cocina_internacional_otras',
#        'productos_frescos_verduras_y_hortalizas_hierbas_aromaticas_y_especias'],
#       dtype=object)

# %% [markdown]
# #MERCADONA

# %%
m1 = df[df['id_reference_supermarket'] == 'M1']
m1.head(1)
# Out:
#                                      category  \
# 1055  agua_y_refrescos_isotonico_y_energetico
#
#                                                  name description  price  \
# 1055  Bebida para deportistas sabor cítrico Hacendado     Botella   0.85
#
#       reference_price reference_unit          insert_date  \
# 1055             0.57              l  2021-03-06 00:00:00
#
#                             product_id id_reference_supermarket
# 1055  cc6af45cd819ddd9c69c7a574b840e29                       M1

# %%
m1.shape
# Out:
# (3329440, 9)

# %%
# Reemplazar el guion bajo (_) por un espacio en blanco en la columna 'categoria'
m1.loc[:, 'category'] = df['category'].str.replace('_', ' ')

# %%
m1["category"].unique()
# Out:
# array(['agua y refrescos isotonico y energetico',
#        'agua y refrescos refresco de cola',
#        'agua y refrescos refresco de naranja y de limon',
#        'agua y refrescos tonica y bitter',
#        'agua y refrescos refresco de te y sin gas',
#        'limpieza y hogar limpieza muebles y multiusos',
#        'bebe alimentacion infantil', 'bodega licores',
#        'bebe biberon chupete y menaje', 'bodega cerveza',
#        'bodega cerveza sin alcohol', 'bodega sidra y cava',
#        'bodega tinto de verano y sangria', 'bodega vino blanco',
#        'bodega vino lambrusco y espumoso', 'bodega vino rosado',
#        'bodega vino tinto',
#        'cacao cafe e infusiones cacao soluble y chocolate a la taza',
#        'congelados helados', 'congelados hielo',
#        'conservas caldos y cremas gazpacho y cremas',
#        'huevos leche y mantequilla leche y bebidas vegetales',
#        'zumos naranja', 'limpieza y hogar detergente y suavizante ropa',
# ...

# %%
lista_categorias_mercadona=["agua y refrescos","aceite especias y salsas","aperitivos","arroz legumbres y pasta","azucar caramelos y chocolate","bebe","bodega","cacao cafe e infusiones","carne","cereales y galletas","charcuteria y quesos","congelados","conservas caldos y cremas","cuidado del cabello","cuidado facial y corporal","fitoterapia y parafarmacia","fruta y verdura","huevos leche y mantequilla","limpieza y hogar","maquillaje","marisco y pescado","mascotas","panaderia y pasteleria","pizzas y platos preparados","postres y yogures","zumos"]

# %%
# Función para buscar y guardar el nombre si está presente en la celda
def buscar_nombre(celda):
    for nombre in lista_categorias_mercadona:
        if nombre in celda:
            return nombre
    return None

# Crear una nueva columna y aplicar la función para buscar los nombres
m1['categorias'] = m1['category'].apply(buscar_nombre)

def buscar_sub(celda):
    for nombre in lista_categorias_mercadona:
        if nombre in celda:
            return celda.replace(nombre, '')
    return None

# Crear una nueva columna y aplicar la función para buscar los nombres
m1['subcategorias'] = m1['category'].apply(buscar_sub)
# Out:
# <ipython-input-133-4f190de99c91>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m1['categorias'] = m1['category'].apply(buscar_nombre)
# <ipython-input-133-4f190de99c91>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m1['subcategorias'] = m1['category'].apply(buscar_sub)

# %%
m1
# Out:
#                                         category  \
# 1055     agua y refrescos isotonico y energetico
# 1056     agua y refrescos isotonico y energetico
# 1057     agua y refrescos isotonico y energetico
# 1058     agua y refrescos isotonico y energetico
# 1059     agua y refrescos isotonico y energetico
# ...                                          ...
# 8223986                    fruta y verdura fruta
# 8223987                  fruta y verdura verdura
# 8223989                  fruta y verdura verdura
# 8223990                    fruta y verdura fruta
# 8223991                  fruta y verdura verdura
#
#                                                     name description  price  \
# 1055     Bebida para deportistas sabor cítrico Hacendado     Botella   0.85
# 1056     Bebida para deportistas sabor cítrico Hacendado      Pack-6   1.92
# 1057     Bebida para deportistas sabor cítrico Hacendado        Lata   0.32
# ...

# %% [markdown]
# #CARREFOUR

# %%
m2 = df[df['id_reference_supermarket'] == 'M2']
m2.head(1)
# Out:
#                   category              name description  price  \
# 2053  bebidas_vinos_rosado  Muga Rosado 2019         NaN   9.15
#
#       reference_price reference_unit          insert_date  \
# 2053             9.15             ud  2021-03-06 00:00:00
#
#                             product_id id_reference_supermarket
# 2053  4a9bb57a9ebbad18dff028c702d70c0e                       M2

# %%
# Reemplazar el guion bajo (_) por un espacio en blanco en la columna 'categoria'
m2.loc[:, 'category'] = df['category'].str.replace('_', ' ')

# %%
m2["category"].unique()
# Out:
# array(['bebidas vinos rosado', 'bebidas vinos blanco',
#        'bebidas alcoholes ron',
#        'bebidas aguas y zumos agua hasta 075 litros',
#        'bebidas cava y champagne cavas',
#        'bebidas aguas y zumos zumos refrigerados',
#        'bebidas vinos generosos y dulces', 'bebidas vinos tinto',
#        'bebidas alcoholes ginebra', 'bebidas cerveza todas las cervezas',
#        'bebidas cerveza negra', 'bebidas cerveza artesanas',
#        'bebidas alcoholes vermouth',
#        'bebidas alcoholes todos los alcoholes',
#        'la despensa conservas sopas y precocinados salteados de verdura arroz y paella',
#        'bebidas alcoholes cockteles y combinados',
#        'bebidas cerveza sin alcohol', 'bebidas cerveza tostada  roja',
#        'bebidas cerveza radler clara',
#        'bebidas aguas y zumos agua de 075 a 2 litros',
#        'bebidas cerveza rubia', 'bebidas refrescos gaseosa',
#        'bebidas refrescos energeticas', 'bebidas refrescos te',
# ...

# %%
lista_categorias_carrefour=["productos frescos","la despensa","perfumeria e higiene","el mercado","congelados","bebidas","limpieza y hogar","bebe","mascotas","parafarmacia"]

# %%
# Función para buscar y guardar el nombre si está presente en la celda
def buscar_nombre(celda):
    for nombre in lista_categorias_carrefour:
        if nombre in celda:
            return nombre
    return None

# Crear una nueva columna y aplicar la función para buscar los nombres
m2['categorias'] = m2['category'].apply(buscar_nombre)

def buscar_sub(celda):
    for nombre in lista_categorias_carrefour:
        if nombre in celda:
            return celda.replace(nombre, '')
    return None

# Crear una nueva columna y aplicar la función para buscar los nombres
m2['subcategorias'] = m2['category'].apply(buscar_sub)
# Out:
# <ipython-input-136-03a9f60720e6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m2['categorias'] = m2['category'].apply(buscar_nombre)
# <ipython-input-136-03a9f60720e6>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m2['subcategorias'] = m2['category'].apply(buscar_sub)

# %%
m2
# Out:
#                                                   category  \
# 2053                                  bebidas vinos rosado
# 2054                                  bebidas vinos blanco
# 2055                                 bebidas alcoholes ron
# 2056                                  bebidas vinos blanco
# 2057           bebidas aguas y zumos agua hasta 075 litros
# ...                                                    ...
# 8223977  perfumeria e higiene depilacion y afeitado afe...
# 8223978  perfumeria e higiene depilacion y afeitado afe...
# 8223979  perfumeria e higiene depilacion y afeitado aft...
# 8223980  perfumeria e higiene depilacion y afeitado aft...
# 8223981  perfumeria e higiene depilacion y afeitado aft...
#
#                                                       name description  price  \
# 2053                                      Muga Rosado 2019         NaN   9.15
# 2054                        Blanc Pescador Espumoso Blanco         NaN   3.99
# ...

# %% [markdown]
# #DIA

# %%
m3 = df[df['id_reference_supermarket'] == 'M3']
m3.head(1)
# Out:
#                                             category  \
# 0  perfumeria_e_higiene_cuidado_facial_protector_...
#
#                                              name description  price  \
# 0  LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
#
#    reference_price reference_unit          insert_date  \
# 0             2.39             ud  2021-03-06 00:00:00
#
#                          product_id id_reference_supermarket
# 0  45d83ce427cf60c02e1e6f3d28f58ed6                       M3

# %%
# Reemplazar el guion bajo (_) por un espacio en blanco en la columna 'categoria'
m3.loc[:, 'category'] = df['category'].str.replace('_', ' ')

# %%
m3.shape
# Out:
# (3200969, 9)

# %%
m3["category"].unique()
# Out:
# array(['perfumeria e higiene cuidado facial protector labial',
#        'perfumeria e higiene higiene intima compresas',
#        'perfumeria e higiene higiene bucal productos protesicos',
#        'perfumeria e higiene higiene bucal seda dental',
#        'perfumeria e higiene higiene bucal cepillos de dientes',
#        'drogueria y limpieza cuidado ropa  suavizante concentrado',
#        'drogueria y limpieza celulosa servilletas de papel',
#        'drogueria y limpieza celulosa papel higienico humedo',
#        'drogueria y limpieza celulosa papel higienico',
#        'drogueria y limpieza celulosa papel de cocina',
#        'drogueria y limpieza celulosa panuelos y tissues',
#        'drogueria y limpieza calzado limpiacalzado',
#        'drogueria y limpieza conservacion alimentos papel horno',
#        'drogueria y limpieza conservacion alimentos bolsas de conservacion',
#        'drogueria y limpieza conservacion alimentos bolsas de congelar',
# ...

# %%
lista_categorias_dia=["al dia","dulces de navidad","soy solidario","productos sin gluten","despensa","frescos","cuidado del hogar","lacteos y huevos","bodega","cuidado personal","drogueria y limpieza","charcuteria y quesos","carniceria","pescados mariscos y ahumados","verduras","frutas","leche huevos y mantequilla","yogures y postres","arroz pastas y legumbres","aceites salsas y especias","conservacion caldos y cremas","panes harinas y masas","cafe cacao e infusiones","azucar chocolates y caramelos","galletas bollos y cereales","patatas fritas encurtidos y frutos secos","pizzas y platos preparados","congelados","agua refrescos y zumos","cervezas vinos y bebidas con alcohol","limpieza y hogar","perfumeria higiene salud","bebe","mascotas","alimentacion","perfumeria e higiene","desayuno","platos preparados","bebidas"]

# %%
# Función para buscar y guardar el nombre si está presente en la celda
def buscar_nombre(celda):
    for nombre in lista_categorias_dia:
        if nombre in celda:
            return nombre
    return None

# Crear una nueva columna y aplicar la función para buscar los nombres
m3['categorias'] = m3['category'].apply(buscar_nombre)

def buscar_sub(celda):
    for nombre in lista_categorias_dia:
        if nombre in celda:
            return celda.replace(nombre, '')
    return None

# Crear una nueva columna y aplicar la función para buscar los nombres
m3['subcategorias'] = m3['category'].apply(buscar_sub)
# Out:
# <ipython-input-128-42776a13c217>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m3['categorias'] = m3['category'].apply(buscar_nombre)
# <ipython-input-128-42776a13c217>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m3['subcategorias'] = m3['category'].apply(buscar_sub)

# %%
m3
# Out:
#                                                   category  \
# 0        perfumeria e higiene cuidado facial protector ...
# 1            perfumeria e higiene higiene intima compresas
# 2            perfumeria e higiene higiene intima compresas
# 3        perfumeria e higiene higiene bucal productos p...
# 4        perfumeria e higiene higiene bucal productos p...
# ...                                                    ...
# 8223869  cuidado personal bano e higiene personal desod...
# 8223870  cuidado personal bano e higiene personal desod...
# 8223871  cuidado personal bano e higiene personal desod...
# 8223872  cuidado personal bano e higiene personal desod...
# 8223988                                      bebidas aguas
#
#                                                       name description  price  \
# 0           LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
# 1               AUSONIA compresas normal alas bolsa 14 uds         NaN   2.49
# ...

# %%
nulos_en_mercadona = m1[m1["categorias"].isnull()]
print(nulos_en_mercadona)
# Out:
# Empty DataFrame
# Columns: [category, name, description, price, reference_price, reference_unit, insert_date, product_id, id_reference_supermarket, categorias, subcategorias]
# Index: []

# %%
nulos_en_carr = m2[m2["categorias"].isnull()]
print(nulos_en_carr)
# Out:
# Empty DataFrame
# Columns: [category, name, description, price, reference_price, reference_unit, insert_date, product_id, id_reference_supermarket, categorias, subcategorias]
# Index: []

# %%
nulos_en_dia = m3[m3["categorias"].isnull()]
print(nulos_en_dia)
# Out:
# Empty DataFrame
# Columns: [category, name, description, price, reference_price, reference_unit, insert_date, product_id, id_reference_supermarket, categorias, subcategorias]
# Index: []

# %%
raw_data_categorias = pd.concat([m1,m2,m3])

# %%
raw_data_categorias
# Out:
#                                                   category  \
# 1055               agua y refrescos isotonico y energetico
# 1056               agua y refrescos isotonico y energetico
# 1057               agua y refrescos isotonico y energetico
# 1058               agua y refrescos isotonico y energetico
# 1059               agua y refrescos isotonico y energetico
# ...                                                    ...
# 8223869  cuidado personal bano e higiene personal desod...
# 8223870  cuidado personal bano e higiene personal desod...
# 8223871  cuidado personal bano e higiene personal desod...
# 8223872  cuidado personal bano e higiene personal desod...
# 8223988                                      bebidas aguas
#
#                                                       name description  price  \
# 1055       Bebida para deportistas sabor cítrico Hacendado     Botella   0.85
# 1056       Bebida para deportistas sabor cítrico Hacendado      Pack-6   1.92
# ...

# %%
raw_data_categorias.to_csv("Raw_data_categorias.csv", index = False)

# %%
# Eliminar columnas
columnas_a_eliminar = ['category', 'description','product_id']
raw_data_simplificado = raw_data_categorias.drop(columns=columnas_a_eliminar)

# %%
raw_data_simplificado
# Out:
#                                                       name  price  \
# 1055       Bebida para deportistas sabor cítrico Hacendado   0.85
# 1056       Bebida para deportistas sabor cítrico Hacendado   1.92
# 1057       Bebida para deportistas sabor cítrico Hacendado   0.32
# 1058                     Bebida isotónica naranja Aquarius   1.55
# 1059                     Bebida isotónica naranja Aquarius   5.92
# ...                                                    ...    ...
# 8223869    TULIPAN NEGRO desodorante original spray 200 ml   2.51
# 8223870            DOVE desodorante original roll on 50 ml   2.49
# 8223871  DIA IMAQE desodorante con extracto de rosa mos...   0.75
# 8223872  DIA IMAQE desodorante para pieles atópicas rol...   0.75
# 8223988             DIA agua mineral natural botella 50 cl   0.22
#
#          reference_price reference_unit          insert_date  \
# 1055                0.57              l  2021-03-06 00:00:00
# ...

# %%
raw_data_simplificado.to_csv("raw_data_simplificado.csv", index=False)
