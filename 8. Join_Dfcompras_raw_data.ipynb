# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
raw=pd.read_csv('/content/drive/MyDrive/MASTER PONTIA/PROJECT JUPYTER/ORGANIZACIÓN_COLUMNAS/raw_data.csv')
df_compras=pd.read_csv('df_compras_100000.csv')

# %%
numero_filas = raw.shape[0]
numero_filas
# Out:
# 8223992

# %%
raw.head()
# Out:
#                                             category  \
# 0  perfumeria_e_higiene_cuidado_facial_protector_...
# 1      perfumeria_e_higiene_higiene_intima_compresas
# 2      perfumeria_e_higiene_higiene_intima_compresas
# 3  perfumeria_e_higiene_higiene_bucal_productos_p...
# 4  perfumeria_e_higiene_higiene_bucal_productos_p...
#
#                                                 name description  price  \
# 0     LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
# 1         AUSONIA compresas normal alas bolsa 14 uds         NaN   2.49
# 2  EVAX Cottonlike compresa super plus con alas b...         NaN   2.79
# 3  POLIDENT tabletas limpiadoras para prótesis de...         NaN   7.95
# 4  IWHITE kit de blanquamiento dental profesional...         NaN  36.99
#
#    reference_price reference_unit          insert_date  \
# 0             2.39             ud  2021-03-06 00:00:00
# 1             0.18             ud  2021-03-06 00:00:00
# ...

# %%
raw.isnull().sum()
# Out:
# category                          0
# name                             98
# description                 5201517
# price                            18
# reference_price                   6
# reference_unit                 5480
# insert_date                       0
# product_id                        0
# id_reference_supermarket          0
# dtype: int64

# %%
#raw_merca=raw[raw['id_reference_supermarket']=='M1']

# %%
numero_filas = raw.shape[0]
numero_filas
# Out:
# 8223992

# %%
num_unicos_columna1 = raw['product_id'].nunique()
num_unicos_columna1
# Out:
# 34071

# %%
raw_=raw.drop_duplicates(subset=['product_id'])

# %%
raw_.isnull().sum()
# Out:
# category                        0
# name                            0
# description                 26481
# price                           1
# reference_price                 1
# reference_unit                  5
# insert_date                     0
# product_id                      0
# id_reference_supermarket        0
# dtype: int64

# %%
numero_filas = raw_.shape[0]
numero_filas
# Out:
# 34071

# %%
df_compras.head(2)
# Out:
#    id_compra fecha_compra  id_cliente                       id_producto
# 0          0   2022-06-02          19  f65b04468e58cc9f604cb097236872fe
# 1          1   2022-08-02          27  ce43ded19a577ac0aaa1e3b0cf2b5f1a

# %%
df_compras.rename(columns={'id_producto':'product_id'}, inplace=True)

# %%
df_compras.head(2)
# Out:
#    id_compra fecha_compra  id_cliente                        product_id
# 0          0   2022-06-02          19  f65b04468e58cc9f604cb097236872fe
# 1          1   2022-08-02          27  ce43ded19a577ac0aaa1e3b0cf2b5f1a

# %%
null_values_sum = df_compras.isnull().sum()

# %%
null_values_sum
# Out:
# id_compra       0
# fecha_compra    0
# id_cliente      0
# product_id      0
# dtype: int64

# %%
raw_
# Out:
#                                                   category  \
# 0        perfumeria_e_higiene_cuidado_facial_protector_...
# 1            perfumeria_e_higiene_higiene_intima_compresas
# 2            perfumeria_e_higiene_higiene_intima_compresas
# 3        perfumeria_e_higiene_higiene_bucal_productos_p...
# 4        perfumeria_e_higiene_higiene_bucal_productos_p...
# ...                                                    ...
# 8214557                    congelados_pizzas_bases_y_masas
# 8214795           cuidado_del_hogar_utensilios_de_limpieza
# 8216696                          postres_y_yogures_bifidus
# 8216858                     cuidado_personal_cuidado_bucal
# 8219863      la_despensa_dulce_y_desayuno_infusiones_y_tes
#
#                                                       name description  price  \
# 0           LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
# 1               AUSONIA compresas normal alas bolsa 14 uds         NaN   2.49
# ...

# %%
df_compras
# Out:
#        id_compra fecha_compra  id_cliente                        product_id
# 0              0   2022-06-02          19  f65b04468e58cc9f604cb097236872fe
# 1              1   2022-08-02          27  ce43ded19a577ac0aaa1e3b0cf2b5f1a
# 2              2   2022-07-09          20  0a56c32642021feae8049bbb840a6153
# 3              3   2022-08-18           5  2f8af1c55f93e0b3e4a0b03e5e0f28b4
# 4              4   2022-06-27           3  d7382d624ca08e4459996938e65935e8
# ...          ...          ...         ...                               ...
# 99995      99995   2022-07-19          27  e98212fd3744bc61ee8664b78381f592
# 99996      99996   2022-08-04          50  30c0d240eb3834a32a4ca8128fa2a546
# 99997      99997   2022-07-11          20  b408c71cf823b99ff6b80e17573d5940
# 99998      99998   2022-07-09           1  beadab32512739ed268a6c4dcf19947e
# 99999      99999   2022-06-27          29  0df17d9bc9b3a7846a4527d8ec94090a
#
# [100000 rows x 4 columns]

# %%
#raw_ = raw_merca.drop(columns=['insert_date','reference_price'])

# %%
#df2_sin_duplicados = raw_merca.drop_duplicates(subset=['product_id'], keep='first')

# %%
result = pd.merge(df_compras, raw_[['product_id', 'category','id_reference_supermarket']], on='product_id', how='left')

# %%
result
# Out:
#        id_compra fecha_compra  id_cliente                        product_id  \
# 0              0   2022-06-02          19  f65b04468e58cc9f604cb097236872fe
# 1              1   2022-08-02          27  ce43ded19a577ac0aaa1e3b0cf2b5f1a
# 2              2   2022-07-09          20  0a56c32642021feae8049bbb840a6153
# 3              3   2022-08-18           5  2f8af1c55f93e0b3e4a0b03e5e0f28b4
# 4              4   2022-06-27           3  d7382d624ca08e4459996938e65935e8
# ...          ...          ...         ...                               ...
# 99995      99995   2022-07-19          27  e98212fd3744bc61ee8664b78381f592
# 99996      99996   2022-08-04          50  30c0d240eb3834a32a4ca8128fa2a546
# 99997      99997   2022-07-11          20  b408c71cf823b99ff6b80e17573d5940
# 99998      99998   2022-07-09           1  beadab32512739ed268a6c4dcf19947e
# 99999      99999   2022-06-27          29  0df17d9bc9b3a7846a4527d8ec94090a
#
# ...

# %%
result_=result[result['id_reference_supermarket']=='M1']
#raw_merca=raw[raw['id_reference_supermarket']=='M1']

# %%
result_['category'].unique()
# Out:
# array(['agua_y_refrescos_isotonico_y_energetico',
#        'agua_y_refrescos_refresco_de_cola'], dtype=object)

# %%
result_.to_csv('df_compras_mercadona.csv', index=False)
